# %%
# %pylab inline
plt.style.use('dark_background')
pylab.rcParams['figure.figsize'] = (10.0, 6.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Trajectory functions and Globals

# %%
def point_to_point_traj(x1, x2, v1, v2, delta_t):
    t = np.linspace(0, delta_t, 100)  
    a0 = x1
    a1 = v1
    a2 = (3*x2 - 3*x1 - 2*v1*delta_t - v2 * delta_t) / (delta_t**2)
    a3 = (2*x1 + (v1 + v2) * delta_t  - 2 * x2) / (delta_t**3)

    polynomial = a0 + a1 * t + a2 * t**2 + a3 * t**3
    derivative = a1 + 2*a2 * t + 3 * a3 * t**2
    print('a0: (%.4f) '%(a0))
    print('a1: (%.4f) '%(a1))
    print('a2: (%.4f) '%(a2))
    print('a3: (%.4f) '%(a3))
    return polynomial, derivative


def piecewise2D (X,Y, Vx, Vy, T):
    theta_x, theta_y, dx, dy = [], [], [], []

    count = 1
    for i in range(len(P)-1):
        print(count)
        count = count+1
        print('x')
        theta_xi, dxi = point_to_point_traj(X[i], X[i+1], Vx[i], Vx[i+1], T[i+1] - T[i])
        print('y')
        theta_yi, dyi = point_to_point_traj(Y[i], Y[i+1], Vy[i], Vy[i+1], T[i+1] - T[i])
        print('=================')
        
        theta_x += theta_xi.tolist()
        theta_y += theta_yi.tolist()
        dx += dxi.tolist()
        dy += dyi.tolist()

        plot(theta_xi, theta_yi)
    return theta_x, theta_y, dx, dy

# %% [markdown]
# # Plotting functions

# %%
# Plotting
def plot_points():
    plot(X,Y, '--')
    plot(X,Y, 'o')
    quiver(X,Y, Vx, Vy, color='r')

def plot_points_3d():
    plot(X,Y,Z, '--')
    plot(X,Y,Z, 'o')
    
# Speed
def plot_speed():
    speed = np.sqrt(np.array(dx)**2 + np.array(dy)**2)
    plot(speed)

# %% [markdown]
# # 1.3 Number 1

# %%
##### Requirements for the trajectory

# Waypoints
p1 = [-5,-7]
p2 = [9.5,-7]
p3 = [9.5, -3]
p4 = [3,-3]
p5 = [3,6]
p6 = [0,6]
p7 = [0,-3]
p8 = [3,-3]
p9 = [3,10]
p10 = [9,10]

# Velocities
v1 = [0.,0.]
v2 = [1,0]
v3 = [0,1]
v4 = [-.5,0]
v5 = [0,1]
v6 = [-1,0]
v7 = [0,-1]
v8 = [1,0]
v9 = [.5,1]
v10 = [0.,0.]

# Time
t1 = 0
t2 = t1 + 3
t3 = t2 + 5
t4 = t3 + 5
t5 = t4 + 3
t6 = t5 + 5
t7 = t6 + 5
t8 = t7 + 2
t9 = t8 + 3
t10 = t9 + 2

# Grouping
P = np.vstack((p1, p2, p3, p4, p5, p6, p7, p8, p9, p10))
V = np.vstack((v1, v2, v3, v4, v5, v6, v7, v8, v9, v10))
T = [t1, t2, t3, t4, t5, t6, t7, t8, t9, t10]

X, Y = P[:,0], P[:,1]
Vx, Vy = V[:,0], V[:,1]

# Plotting line function
plot_points()
show()

# Piecewise function for spline
theta_x, theta_y, dx, dy = piecewise2D(X,Y, Vx, Vy, T)

# Plotting
# Add obstacles for visualization
rect1 = plt.Rectangle((4, -1), 2, 10, fc='r')
rect2 = plt.Rectangle((.5,2), 2, 3, fc='r')
rect3 = plt.Rectangle((-6,-5), 15, 1, fc='r')
rect4 = plt.Rectangle((8,0), 2, 5, fc='r')
rect5 = plt.Rectangle((-4,-3), 2, 8, fc='r')
plt.gca().add_patch(rect1)
plt.gca().add_patch(rect2)
plt.gca().add_patch(rect3)
plt.gca().add_patch(rect4)
plt.gca().add_patch(rect5)

# Graph the lines
quiver(X,Y, Vx, Vy, color='r')

#show()
#plot_speed()
# Out:
# 1
# x
# a0: (-5.0000)
# a1: (0.0000)
# a2: (4.5000)
# a3: (-0.9630)
# y
# a0: (-7.0000)
# a1: (0.0000)
# a2: (0.0000)
# a3: (0.0000)
# ...
# 2
# x
# a0: (9.5000)
# a1: (1.0000)
# a2: (-0.4000)
# a3: (0.0400)
# y
# a0: (-7.0000)
# a1: (0.0000)
# a2: (0.2800)
# a3: (-0.0240)
# ...
# 3
# x
# a0: (9.5000)
# a1: (0.0000)
# a2: (-0.6800)
# a3: (0.0840)
# y
# a0: (-3.0000)
# a1: (1.0000)
# a2: (-0.4000)
# a3: (0.0400)
# ...
# 4
# x
# a0: (3.0000)
# a1: (-0.5000)
# a2: (0.3333)
# a3: (-0.0556)
# y
# a0: (-3.0000)
# a1: (0.0000)
# a2: (2.6667)
# a3: (-0.5556)
# ...
# 5
# x
# a0: (3.0000)
# a1: (0.0000)
# a2: (-0.1600)
# a3: (0.0080)
# y
# a0: (6.0000)
# a1: (1.0000)
# a2: (-0.4000)
# a3: (0.0400)
# ...
# 6
# x
# a0: (0.0000)
# a1: (-1.0000)
# a2: (0.4000)
# a3: (-0.0400)
# y
# a0: (6.0000)
# a1: (0.0000)
# a2: (-0.8800)
# a3: (0.1040)
# ...
# 7
# x
# a0: (0.0000)
# a1: (0.0000)
# a2: (1.7500)
# a3: (-0.5000)
# y
# a0: (-3.0000)
# a1: (-1.0000)
# a2: (1.0000)
# a3: (-0.2500)
# ...
# 8
# x
# a0: (3.0000)
# a1: (1.0000)
# a2: (-0.8333)
# ...

# %% [markdown]
# # 1.3 Number 3

# %%
##### Requirements for the trajectory

# Waypoints
p1 = [7.6250, 8.5500] #Start
p2 = [0.4000, 8.0500] #Sphere1
p3 = [4.6000, 6.6000] #Checkpoint1
p4 = [1.9250, 2.2250] #Sphere
p5 = [7.2500, 2.2250] #Checkpoint2
p6 = [4.8000, -2.5000] #Sphere2
p7 = [0.7755,-6.5250] #Checkpoint3
p8 = [6.1250, -6.1500] #Sphere3
p9 = [8.8500, -2.5000] #Checkpoint4
p10 = [4.8000, -2.5000] #Checkpoint5 - back to Sphere2
p11 = [-1.2000, -3.0750] #Checkpoint6
p12 = [-3.7500, 0.0000] #Checkpoint7
p13 = [-3.7500, 5.000] #Through Sphere0
p14 = [-7.8500, 5.2250] #Checkpoint8
p15 = [-5.0750, -4.5750] #Checkpoint9
p16 = [-3.4500, -7.0750] #Checkpoint10
p17 = [-6.6500, -8.5000] #Sphere4

# Velocities
v1 = [0,0] #Start
v2 = [0,.5] #Sphere1
v3 = [.25,-.75] #Checkpoint1
v4 = [-.25,.25] #Sphere
v5 = [.1,0] #Checkpoint2
v6 = [-1,0] #Sphere2
v7 = [.5,0] #Checkpoint3
v8 = [1.5,0] #Sphere3
v9 = [0,.75] #Checkpoint4
v10 = [-1,0] #Checkpoint5 - back to Sphere2
v11 = [-.1,1] #Checkpoint6
v12 = [-.05,1] #Checkpoint7
v13 = [0,1] #Through Sphere0
v14 = [.5,-1] #Checkpoint8
v15 = [1,-.25] #Checkpoint9
v16 = [0,-.5] #Checkpoint10
v17 = [0,0] #Sphere4

# Time
t1 = 0
t2 = t1 + 10
t3 = t2 + 10
t4 = t3 + 10
t5 = t4 + 10
t6 = t5 + 10
t7 = t6 + 10
t8 = t7 + 10
t9 = t8 + 10
t10 = t9 + 10
t11 = t10 + 10
t12 = t11 + 10
t13 = t12 + 10
t14 = t13 + 10
t15 = t14 + 10
t16 = t15 + 10
t17 = t16 + 10

# Grouping
P = np.vstack((p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12, p13, p14, p15, p16, p17))
V = np.vstack((v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12, v13, v14, v15, v16, v17))
T = [t1, t2, t3, t4, t5, t6, t7, t8, t9, t10, t11, t12, t13, t14, t15, t16, t17]

X, Y = P[:,0], P[:,1]
Vx, Vy = V[:,0], V[:,1]

# Plotting
plot_points()
show()

# Piecewise function
theta_x, theta_y, dx, dy, = piecewise2D(X,Y, Vx,Vy, T)

#show()
#plot_speed()
# Out:
# 1
# x
# a0: (7.6250)
# a1: (0.0000)
# a2: (-0.2167)
# a3: (0.0144)
# y
# a0: (8.5500)
# a1: (0.0000)
# a2: (-0.0650)
# a3: (0.0060)
# ...
# 2
# x
# a0: (0.4000)
# a1: (0.0000)
# a2: (0.1010)
# a3: (-0.0059)
# y
# a0: (8.0500)
# a1: (0.5000)
# a2: (-0.0685)
# a3: (0.0004)
# ...
# 3
# x
# a0: (4.6000)
# a1: (0.2500)
# a2: (-0.1052)
# a3: (0.0053)
# y
# a0: (6.6000)
# a1: (-0.7500)
# a2: (-0.0062)
# a3: (0.0037)
# ...
# 4
# x
# a0: (1.9250)
# a1: (-0.2500)
# a2: (0.1998)
# a3: (-0.0122)
# y
# a0: (2.2250)
# a1: (0.2500)
# a2: (-0.0500)
# a3: (0.0025)
# ...
# 5
# x
# a0: (7.2500)
# a1: (0.1000)
# a2: (0.0065)
# a3: (-0.0041)
# y
# a0: (2.2250)
# a1: (0.0000)
# a2: (-0.1418)
# a3: (0.0095)
# ...
# 6
# x
# a0: (4.8000)
# a1: (-1.0000)
# a2: (0.0293)
# a3: (0.0030)
# y
# a0: (-2.5000)
# a1: (0.0000)
# a2: (-0.1208)
# a3: (0.0080)
# ...
# 7
# x
# a0: (0.7755)
# a1: (0.5000)
# a2: (-0.0895)
# a3: (0.0093)
# y
# a0: (-6.5250)
# a1: (0.0000)
# a2: (0.0112)
# a3: (-0.0008)
# ...
# 8
# x
# a0: (6.1250)
# a1: (1.5000)
# a2: (-0.2183)
# ...

# %% [markdown]
# # 1.3 Number 4

# %%
# Trajectory functions

def piecewise3D (X,Y,Z, Vx,Vy,Vz, T):
    theta_x, theta_y, theta_z, dx, dy, dz = [], [], [], [], [], []
    
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    count = 1
    for i in range(len(P)-1):          
        print(count)
        print('x:')
        theta_xi, dxi = point_to_point_traj(X[i], X[i+1], Vx[i], Vx[i+1], T[i+1] - T[i])
        print('y:')
        theta_yi, dyi = point_to_point_traj(Y[i], Y[i+1], Vy[i], Vy[i+1], T[i+1] - T[i])
        print('z:')
        theta_zi, dzi = point_to_point_traj(Z[i], Z[i+1], Vz[i], Vz[i+1], T[i+1] - T[i])
        print('=================')
        theta_x += theta_xi.tolist()
        theta_y += theta_yi.tolist()
        theta_z += theta_zi.tolist()
        dx += dxi.tolist()
        dy += dyi.tolist()
        dz += dzi.tolist()
        count+=1
        
        ax.plot3D(theta_xi, theta_yi, theta_zi)
        #plot(theta_xi, theta_yi, theta_zi)
        
    return theta_x, theta_y, theta_z, dx, dy, dz

# %%
##### Requirements for the trajectory

# Waypoints
p1 = [9.1750, 8.0250, 0.5100] #Start
p2 = [6.9750, 8.0250, 3.7500] #Checkpoint1
p3 = [6.9750, 1.2000, 1.4750] #Sphere10
p4 = [6.5750, -3.9250, 3.5000] #Checkpoint2
p5 = [4.6250, -6.8500, 1.4750] #Sphere8
p6 = [-2.0000, -8.0000, 3.0000] #Checkpoint3
p7 = [-9.000, -8.4750, 1.5500] #Sphere9
p8 = [-9.000, -8.4750, 4.000] #Checkpoint4
p9 = [-3.7750, 3.3000, 5.6250] #Sphere5(upper)
p10 = [-3.7250, 6.5000, 4.000] #Checkpoint5
p11 = [-3.7750, 3.3000, 1.9500] #Sphere6(lower)
p12 = [1.8500, 2.6750, 1.4750] #Sphere7(tricky)

# Velocities
v1 = [0,0,1] #Start
v2 = [0,-1,0] #Checkpoint1
v3 = [0,-1,-.1] #Sphere10
v4 = [0,-.5,0] #Checkpoint2
v5 = [-1,0,0] #Sphere8
v6 = [-1,0,0] #Checkpoint3
v7 = [-1,0,0] #Sphere9
v8 = [.5,.5,0] #Checkpoint 4
v9 = [0,.5,0] #Sphere5
v10 = [0,0,-.5] #Checkpoint
v11 = [0,-.5, 0] #Sphere6
v12 = [0,0,0] #Sphere7

# Time
t1 = 0
t2 = t1+10
t3 = t2+10
t4 = t3+10
t5 = t4+10
t6 = t5+10
t7 = t6+10
t8 = t7+10
t9 = t8+10
t10 = t9+10
t11 = t10+10
t12 = t11+10

# Grouping
P = np.vstack((p1, p2, p3, p4, p5, p6, p7, p8, p9, p10, p11, p12))
V = np.vstack((v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11, v12))
T = [t1, t2, t3, t4, t5, t6, t7, t8, t9, t10, t11, t12]

X, Y, Z = P[:,0], P[:,1], P[:,2]
Vx, Vy, Vz = V[:,0], V[:,1], V[:,2]

# Plotting
#plot_points()
#show()

# Piecewise function
theta_x, theta_y, theta_z, dx, dy, dz = piecewise3D(X,Y,Z, Vx,Vy,Vz, T)

#show()
#plot_speed()
# Out:
# 1
# x:
# a0: (9.1750)
# a1: (0.0000)
# a2: (-0.0660)
# a3: (0.0044)
# y:
# a0: (8.0250)
# a1: (0.0000)
# a2: (0.1000)
# a3: (-0.0100)
# z:
# a0: (0.5100)
# a1: (1.0000)
# a2: (-0.1028)
# a3: (0.0035)
# ...
# 2
# x:
# a0: (6.9750)
# a1: (0.0000)
# a2: (0.0000)
# a3: (0.0000)
# y:
# a0: (8.0250)
# a1: (-1.0000)
# a2: (0.0952)
# a3: (-0.0063)
# z:
# a0: (3.7500)
# a1: (0.0000)
# a2: (-0.0582)
# a3: (0.0035)
# ...
# 3
# x:
# a0: (6.9750)
# a1: (0.0000)
# a2: (-0.0120)
# a3: (0.0008)
# y:
# a0: (1.2000)
# a1: (-1.0000)
# a2: (0.0963)
# a3: (-0.0047)
# z:
# a0: (1.4750)
# a1: (-0.1000)
# a2: (0.0807)
# a3: (-0.0050)
# ...
# 4
# x:
# a0: (6.5750)
# a1: (0.0000)
# a2: (0.0415)
# a3: (-0.0061)
# y:
# a0: (-3.9250)
# a1: (-0.5000)
# a2: (0.0123)
# a3: (0.0008)
# z:
# a0: (3.5000)
# a1: (0.0000)
# a2: (-0.0607)
# a3: (0.0040)
# ...
# 5
# x:
# a0: (4.6250)
# a1: (-1.0000)
# a2: (0.1013)
# a3: (-0.0067)
# y:
# a0: (-6.8500)
# a1: (0.0000)
# a2: (-0.0345)
# a3: (0.0023)
# z:
# a0: (1.4750)
# a1: (0.0000)
# a2: (0.0457)
# ...
